# %%
##importing the libraries
import pandas as pd
import numpy as np

# %%
##reading the dataset
dataset = pd.read_excel('Real estate valuation data set.xlsx')

# %%
##showing the dataset
dataset.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
##dataset columns for our convinience
dataset.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
##droping the first two columns because we dont require that right now 
dataset.drop(['No', 'X1 transaction date'],axis = 1,inplace = True)

# %%
dataset.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
## altering the dataset because the distance between the expected and real answer looks too uch so to minimize it we are going to take everything in decimal points 
##
dataset['X2 house age'] = dataset['X2 house age']/100
dataset['X3 distance to the nearest MRT station'] = dataset['X3 distance to the nearest MRT station']/1000
dataset['X4 number of convenience stores'] = dataset['X4 number of convenience stores']/10
dataset['X5 latitude'] = dataset['X5 latitude']/100
dataset['X6 longitude'] = dataset['X6 longitude']/1000
dataset['Y house price of unit area'] = dataset['Y house price of unit area']/100

# %%
##renaming for my convinienece
dataset['X1'] = dataset['X2 house age']
dataset['X2'] = dataset['X3 distance to the nearest MRT station']
dataset['X3'] = dataset['X4 number of convenience stores']
dataset['X4'] = dataset['X5 latitude']
dataset['X5'] = dataset['X6 longitude']
dataset['Y'] = dataset['Y house price of unit area']
##droping teh columns because we have copy of all the other columns 
dataset.drop(['X2 house age',
       'X3 distance to the nearest MRT station',
       'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
       'Y house price of unit area'],axis =1 ,inplace = True)

# %%
dataset.head()
# Out:
#       X1        X2   X3        X4        X5      Y
# 0  0.320  0.084879  1.0  0.249830  0.121540  0.379
# 1  0.195  0.306595  0.9  0.249803  0.121540  0.422
# 2  0.133  0.561984  0.5  0.249875  0.121544  0.473
# 3  0.133  0.561984  0.5  0.249875  0.121544  0.548
# 4  0.050  0.390568  0.5  0.249794  0.121542  0.431

# %%
dataset.drop(['Y'],axis =1 ,inplace =True)

# %%
dataset.head()
# Out:
#       X1        X2   X3        X4        X5
# 0  0.320  0.084879  1.0  0.249830  0.121540
# 1  0.195  0.306595  0.9  0.249803  0.121540
# 2  0.133  0.561984  0.5  0.249875  0.121544
# 3  0.133  0.561984  0.5  0.249875  0.121544
# 4  0.050  0.390568  0.5  0.249794  0.121542

# %%
x = dataset.iloc[:,:].values

# %%
weights = np.random.uniform(size = (2,1))

# %%
weights
# Out:
# array([[0.44209753],
#        [0.60171963]])

# %%
l = x[0]
l
# Out:
# array([0.32      , 0.08487882, 1.        , 0.2498298 , 0.12154024])

# %%
weights[1,0]
# Out:
# 0.6017196278495036

# %%
first_weights = weights[0,0]
second_weights = weights[1,0]

# %%
##getting the learning rate
leanring_rate = np.random.rand()

# %%
learning_rate = leanring_rate

# %%
## we are going to categories into two clusters so we are just taking two variable and calculate which cluster will belong to which cluster

first_weight = 0.3
second_weight = 0.7

# %%
##      ________________ALGORITHM____________________
##      initialize weights
##      try to find which weight is neare to those points (Xi-weights i)^2
##      put that point to \that cluster 
##      update the weights for all the points
##      decrease the topoloogy

##answer list  for the answers 
answer = []
for l in x:
    for i in range(5):
        ##calculate the weights that is which will belong to which cluster 
        first_weight = (l[i] - first_weight)
        second_weight = (l[i]-second_weight)
    ##finding minimun
    if(first_weight>second_weight):
        answer.append(2)
    else:
        answer.append(1)
    print(first_weight,second_weight)
    ##updationg of the weights
    for p in range(5):
        first_weight = first_weight+(learning_rate*(l[p]-first_weight))
        second_weight = second_weight + (learning_rate*(l[i]-second_weight))
    learning_rate = learning_rate*0.05
# Out:
# 0.80683162 0.40683161999999995
# 0.3959635709310802 0.5336328452591039
# -0.4476776088878617 -0.5368400416674003
# 0.3850968433396502 0.47496849684810216
# -0.3538915758446518 -0.44366552994483666
# -1.5782670760244408 -1.4884922359930477
# 1.8715352208163476 1.7817608593645966
# -1.4843995773360796 -1.3946252073549514
# -3.738663346517193 -3.8284377159331178
# 2.306325105975169 2.396099475504814
# -2.3917396859655202 -2.481514055492482
# 3.136083425964806 3.2258577954917755
# -3.126428855964767 -3.2162032254917334
# 1.132683515964765 1.2224578854917316
# -1.8939030559647652 -1.9836774254917318
# 1.7434169459647655 1.833191315491732
# -1.5646445659647652 -1.6544189354917318
# 1.3625698559647652 1.4523442254917318
# -0.8898366459647652 -0.9796110154917318
# 1.453317625964765 1.5430919954917317
# -3.5123145159647655 -3.602088885491732
# 3.9099345259647658 3.9997088954917324
# -5.151045505964766 -5.240819875491733
# 5.544665515964766 5.634439885491733
# ...

# %%
dataset['cluster belonges'] = answer

# %%
## if you look we can now see which data points belongs to which clusters with the clumnname cluster belongs 
dataset
# Out:
#         X1        X2   X3        X4        X5  cluster belonges
# 0    0.320  0.084879  1.0  0.249830  0.121540                 2
# 1    0.195  0.306595  0.9  0.249803  0.121540                 1
# 2    0.133  0.561984  0.5  0.249875  0.121544                 2
# 3    0.133  0.561984  0.5  0.249875  0.121544                 1
# 4    0.050  0.390568  0.5  0.249794  0.121542                 2
# 5    0.071  2.175030  0.3  0.249630  0.121513                 1
# 6    0.345  0.623473  0.7  0.249793  0.121536                 2
# 7    0.203  0.287603  0.6  0.249804  0.121542                 1
# 8    0.317  5.512038  0.1  0.249509  0.121485                 2
# 9    0.179  1.783180  0.3  0.249673  0.121515                 1
# 10   0.348  0.405213  0.1  0.249735  0.121534                 2
# 11   0.063  0.090456  0.9  0.249743  0.121543                 1
# 12   0.130  0.492231  0.5  0.249652  0.121537                 2
# 13   0.204  2.469645  0.4  0.249611  0.121510                 1
# ...

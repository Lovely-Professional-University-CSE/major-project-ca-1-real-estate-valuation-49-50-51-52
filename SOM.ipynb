# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
dataset = pd.read_excel('Real estate valuation data set.xlsx')

# %%
dataset.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
dataset.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
dataset['X2 house age'].plot.hist()

# %%
dataset.drop(['No', 'X1 transaction date','X3 distance to the nearest MRT station','X5 latitude','X4 number of convenience stores', 'X6 longitude'],axis =1,inplace =True)

# %%
dataset.head()
# Out:
#    X2 house age  Y house price of unit area
# 0          32.0                        37.9
# 1          19.5                        42.2
# 2          13.3                        47.3
# 3          13.3                        54.8
# 4           5.0                        43.1

# %%
x = dataset.iloc[:,:-1]
df = dataset

# %%
x
# Out:
#      X2 house age
# 0            32.0
# 1            19.5
# 2            13.3
# 3            13.3
# 4             5.0
# 5             7.1
# 6            34.5
# 7            20.3
# 8            31.7
# 9            17.9
# 10           34.8
# 11            6.3
# 12           13.0
# 13           20.4
# 14           13.2
# 15           35.7
# 16            0.0
# 17           17.7
# 18           16.9
# 19            1.5
# 20            4.5
# 21           10.5
# 22           14.7
# 23           10.1
# 24           39.6
# 25           29.3
# 26            3.1
# 27           10.4
# 28           19.2
# 29            7.1
# ..            ...
# 384          16.1
# 385          18.3
# 386           0.0
# 387          16.2
# 388          10.4
# 389          40.9
# 390          32.8
# 391           6.2
# 392          42.7
# 393          16.9
# 394          32.6
# 395          21.2
# 396          37.1
# 397          13.1
# 398          14.7
# 399          12.7
# 400          26.8
# 401           7.6
# ...

# %%
y = dataset.iloc[:,-1:]
y
# Out:
#      Y house price of unit area
# 0                          37.9
# 1                          42.2
# 2                          47.3
# 3                          54.8
# 4                          43.1
# 5                          32.1
# 6                          40.3
# 7                          46.7
# 8                          18.8
# 9                          22.1
# 10                         41.4
# 11                         58.1
# 12                         39.3
# 13                         23.8
# 14                         34.3
# 15                         50.5
# 16                         70.1
# 17                         37.4
# 18                         42.3
# 19                         47.7
# 20                         29.3
# 21                         51.6
# 22                         24.6
# 23                         47.9
# 24                         38.8
# 25                         27.0
# 26                         56.2
# 27                         33.6
# ...

# %%
plt.scatter(x,y)

# %%
weights ={
    i+1:[np.random.randint(0,40),np.random.randint(0,40)]
    for i in range(2)
}
p = []
q = []
for v in weights.values():
    p.append(v[0])
    q.append(v[1])
    
plt.scatter(p,q)
plt.xlim(0,80)
plt.ylim(0,80)
# Out:
# (0, 80)

# %%
weights
centroids = weights

# %%
def assignment(df, centroids):
    
    
    
    
    return df

df = assignment(df, centroids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-3cf3d7a38c20> in <module>()
#      10     return df
#      11
# ...
